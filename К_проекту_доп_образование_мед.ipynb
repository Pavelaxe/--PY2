             'Мариинская_больница,_отделение_неврологии' : 'mariinskaya_bolnitsa_otdeleniye_nevrologii/206108858605',
             'СПб_ГБУЗ_ГКБ_№_46_Святой_Евгении' : 'spb_gbuz_gkb_46_svyatoy_yevgenii/1783368302',
             'Покровская_сердечно-сосудистая_больница' : 'pokrovskaya_serdechno_sosudistaya_bolnitsa/172778855247',
             'ФГБУ_Нмиц_ТО_им._Р._Р._Вредена_Минздрава_России' : 'fgbu_nmits_to_im_r_r_vredena_minzdrava_rossii/1223387426',
             'Мариинская_больница,_Гинекологическое_отделение' : 'mariinskaya_bolnitsa_ginekologicheskoye_otdeleniye/1870786888',
             'Мариинская_больница,_Приёмное_отделение' : 'mariinskaya_bolnitsa_priyomnoye_otdeleniye/1885620159',
             'ФГБУ_СПб_НИИФ_Минздрава_России' : 'fgbu_spb_niif_minzdrava_rossii/1033293026',
             'Больница_№_20' : 'bolnitsa_20/163268183603',
             'Городская_наркологическая_больница' : 'gorodskaya_narkologicheskaya_bolnitsa/1129547632',
             'Детская_городская_клиническая_больница_№_5_им._Н.Ф._Филатова' : 'detskaya_gorodskaya_klinicheskaya_bolnitsa_5_im_n_f_filatova/1226037553',
             'Детская_городская_больница_№_19_им._К._А._Раухфуса' : 'detskaya_gorodskaya_bolnitsa_19_im_k_a_raukhfusa/1819316432',
             'Клиническая_инфекционная_больница_имени_С._П._Боткина,_дневной_стационар' : 'klinicheskaya_infektsionnaya_bolnitsa_imeni_s_p_botkina_dnevnoy_statsionar/244413506610',
             'СПб_ГБУЗ_Городская_больница_№_14' : 'spb_gbuz_gorodskaya_bolnitsa_14/1500985789',
             'СПбГБУЗ_Городская_больница_№_20' : 'spbgbuz_gorodskaya_bolnitsa_20/1026119140',
             'ГБУЗ_Локб,_нейрохирургическое_отделение' : 'gbuz_lokb_neyrokhirurgicheskoye_otdeleniye/222427662772',
             'СПб_ГБУЗ_Елизаветинская_больница' : 'spb_gbuz_yelizavetinskaya_bolnitsa/30341700065',
             'СПб_ГБУЗ_Городская_больница_№_15,_хирургический_корпус' : 'spb_gbuz_gorodskaya_bolnitsa_15_khirurgicheskiy_korpus/1230186848',
             'СПб_ГБУЗ_Городская_больница_№_15' : 'spb_gbuz_gorodskaya_bolnitsa_15/146348612299',
             'Санкт-Петербургское_ГКУЗ_Городская_психиатрическая_больница_№_3_им._И._И._Скворцова-Степанова' : 'sankt_peterburgskoye_gkuz_gorodskaya_psikhiatricheskaya_bolnitsa_3_im_i_i_skvortsova_stepanova/1111358565'}

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from bs4 import BeautifulSoup
import pandas as pd

options = webdriver.ChromeOptions()

options.add_experimental_option('excludeSwitches', ['enable-automation']) 

options.add_experimental_option('useAutomationExtension', False)

driver = webdriver.Chrome(executable_path = '/Users/1208024/Documents/python/Важное/chromedriver', chrome_options = options) 

driver.maximize_window() 

for k, v in hospitals.items():
    driver.get(f'https://yandex.ru/maps/org/{v}/reviews/')
    time.sleep(3)

    try:
        driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div[7]/div[1]/div[1]/div[1]/div/div[1]/div/div[3]/div/div[3]/div/div/div[5]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div').click()
        time.sleep(1)
    except:
        driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div[7]/div[1]/div[1]/div[1]/div/div[1]/div/div[3]/div/div[3]/div/div/div[6]/div/div[2]/div/div[1]/div[2]/div/div[2]/div[2]/div[1]/div/div/div/div').click()
        time.sleep(1)
        
    for i in range(240):
        ActionChains(driver).send_keys(Keys.PAGE_DOWN).perform()
        time.sleep(0.2)

    pages = []
    pages.append(driver.page_source)

    inf = BeautifulSoup(pages[0])

    feedback = inf.findAll('span', {'class' : 'business-review-view__body-text'})
    FEEDBACK = []
    for x in feedback:
        FEEDBACK.append(x.text.strip())

    date = inf.findAll('span', {'class' : 'business-review-view__date'})
    DATE = []
    for x in date:
        DATE.append(x.text.strip())

    status = inf.findAll('div', {'class' : 'business-review-view__author-profession'})
    STATUS = []
    for x in status:
        STATUS.append(x.text.strip())

    name = inf.findAll('span', {'itemprop' : 'name'})
    NAME = []
    for x in name:
        NAME.append(x.text.strip())

    full_list = list(zip(FEEDBACK, DATE, NAME))
    df = pd.DataFrame(full_list, columns = ['Текст отзыва', 
                                            'Даты',  
                                            'Имя комментатора'])

    df.to_excel(f'{k}.xlsx')

# %%
list_of_hospitals = ['Александровская_больница',
 'Больница_№_20',
 'Больница_№_4_Святого_Георгия',
 'Введенская_городская_клиническая_больница',
 'ГБУЗ_Городская_больница_№_26',
 'ГБУЗ_Клиническая_больница_Святителя_Луки_Санкт-Петербургская',
 'ГБУЗ_Ленинградская_областная_клиническая_больница',
 'ГБУЗ_Локб,_нейрохирургическое_отделение',
 'ГБУЗ_городская_поликлиника_№_25_Невского_района',
 'ГБУЗ_городская_поликлиника_№_28',
 'ГБУЗ_городская_поликлиника_№_87',
 'ГБУЗ_поликлиника_№_88,_поликлиническое_отделение_№_45',
 'Городская поликлиника_№_4,_Детское_Поликлиническое_отделение_№_1',
 'Городская_больница_№_20_аптека',
 'Городская_больница_№_9',
 'Городская_клиническая_больница_№_31',
 'Городская_многопрофильная_больница_№_2',
 'Городская_наркологическая_больница',
 'Городская_поликлиника_№_100',
 'Городская_поликлиника_№_102',
 'Городская_поликлиника_№_106,_взрослое_отделение_№_124',
 'Городская_поликлиника_№_109',
 'Городская_поликлиника_№_111',
 'Городская_поликлиника_№_112',
 'Городская_поликлиника_№_114',
 'Городская_поликлиника_№_17',
 'Городская_поликлиника_№_24',
 'Городская_поликлиника_№_27',
 'Городская_поликлиника_№_32',
 'Городская_поликлиника_№_39',
 'Городская_поликлиника_№_4,_поликлиническое_отделение_№_4',
 'Городская_поликлиника_№_4,_поликлиническое_отделение_№_53',
 'Городская_поликлиника_№_44',
 'Городская_поликлиника_№_6',
 'Городская_поликлиника_№_76',
 'Городская_поликлиника_№_77_Невского_района',
 'Городская_поликлиника_№_83',
 'Городская_поликлиника_№_86',
 'Городская_поликлиника_№_91,_взрослое_поликлиническое_отделение_105',
 'Городская_поликлиника_№_94',
 'Детская_больница_№_2_Святой_Марии_Магдалины',
 'Детская_городская_больница_святой_Ольги',
 'Детская_городская_больница_№_19_им._К._А._Раухфуса',
 'Детская_городская_больница_№_2_Святой_Марии_Магдалины',
 'Детская_городская_клиническая_больница_№_5_им._Н.Ф._Филатова',
import torch
from transformers import BertForSequenceClassification, AutoTokenizer

LABELS = ['neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust']
tokenizer = AutoTokenizer.from_pretrained('Aniemore/rubert-tiny2-russian-emotion-detection')
model = BertForSequenceClassification.from_pretrained('Aniemore/rubert-tiny2-russian-emotion-detection')

@torch.no_grad()
def predict_emotion(text: str) -> str:
    """
        We take the input text, tokenize it, pass it through the model, and then return the predicted label
        :param text: The text to be classified
        :type text: str
        :return: The predicted emotion
    """
    inputs = tokenizer(text, max_length=512, padding=True, truncation=True, return_tensors='pt')
    outputs = model(**inputs)
    predicted = torch.nn.functional.softmax(outputs.logits, dim=1)
    predicted = torch.argmax(predicted, dim=1).numpy()
        
    return LABELS[predicted[0]]

@torch.no_grad()    
def predict_emotions(text: str) -> list:
    """
        It takes a string of text, tokenizes it, feeds it to the model, and returns a dictionary of emotions and their
        probabilities
        :param text: The text you want to classify
        :type text: str
        :return: A dictionary of emotions and their probabilities.
    """
    inputs = tokenizer(text, max_length=512, padding=True, truncation=True, return_tensors='pt')
    outputs = model(**inputs)
    predicted = torch.nn.functional.softmax(outputs.logits, dim=1)
    emotions_list = {}
    for i in range(len(predicted.numpy()[0].tolist())):
        emotions_list[LABELS[i]] = predicted.numpy()[0].tolist()[i]
    return emotions_list

# %%
for hospital in list_of_hospitals:
    df = pd.read_excel(f'{hospital}.xlsx')
    posts = df['Текст отзыва']
    posts_new = []
    for y in posts:
        posts_new.append(str(y))
    print(len(posts_new))
    sentenses_full_list = []
    for text in tqdm(posts_new):
            m = predict_emotions(text)
            sentenses_full_list.append(m)

    neutral = []
    happiness = []
    sadness = []
    enthusiasm = []
    fear = []
    anger = []
    disgust = []

    for x in sentenses_full_list:
        neutral.append(x['neutral'])
    for x in sentenses_full_list:
        happiness.append(x['happiness'])
    for x in sentenses_full_list:
        sadness.append(x['sadness'])
    for x in sentenses_full_list:
        enthusiasm.append(x['enthusiasm'])
    for x in sentenses_full_list:
        fear.append(x['fear'])
    for x in sentenses_full_list:
        anger.append(x['anger'])
    for x in sentenses_full_list:
        disgust.append(x['disgust'])

    df['neutral'] = neutral
    df['happiness'] = happiness
    df['sadness'] = sadness
    df['enthusiasm'] = enthusiasm
    df['fear'] = fear
    df['anger'] = anger
    df['disgust'] = disgust
    df.to_excel(f'{hospital}.xlsx')

# %%
Hirurg = []
list_of_tokens_for_Hirurg = ['хирург']

Ginekolog = []
list_of_tokens_for_Ginekolog = ['гинеколог']

Urolog = []
list_of_tokens_for_Urolog = ['уролог']

Okulist = []
list_of_tokens_for_Okulist = ['окулист', 'офтальмолог']

Terapevt = []
list_of_tokens_for_Terapevt = ['терапевт', 'участковый']

Travmatolog = []
list_of_tokens_for_Travmatolog = ['травматол']

Med_sestra = []
list_of_tokens_for_Med_sestra = ['медсестр', 'медсёстр', 'медсетр', 'медскстр',
                                 'медссестра', 'медсесестра', 'медсестп', 'медсес']

Ortoped = []
list_of_tokens_for_Ortoped = ['ортопед']

Onkolog = []
list_of_tokens_for_Onkolog = ['онколог', 'онкобо', 'онкоц', 'онкод', 'онкох',
                                  'онкооф', 'онког']

Gastroenterolog = []
list_of_tokens_for_Gastroenterolog = ['гастроэнт', 'гастролог', 'гастроинт',
                                      'гастроско', 'гастроо', 'гастроэте']

Endokrinolog = []
list_of_tokens_for_Endokrinolog = ['эндокри', 'эндокре']

Allergolog = []
list_of_tokens_for_Allergolog = ['аллергол', 'аллергоо']

Stomatolog = []
list_of_tokens_for_Stomatolog = ['стоматолог', 'зубной']

Flebolog = []
list_of_tokens_for_Flebolog = ['флеболог']

Anasteziolog = []
list_of_tokens_for_Anasteziolog = ['анастезиол']

Reanimatolog = []
list_of_tokens_for_Reanimatolog = ['реаниматоло']

Nefrolog = []
list_of_tokens_for_Nefrolog = ['нефролог']

Narkolog = []
list_of_tokens_for_Narkolog = ['нарколог']

Psihiatr = []
list_of_tokens_for_Psihiatr = ['психиат']

Kardiolog = []
list_of_tokens_for_Kardiolog = ['кардиолог', 'кардио']

Nevrolog = []
list_of_tokens_for_Nevrolog = ['невролог', 'невропатол', 'невропотол']

Pylmonolog = []
list_of_tokens_for_Pylmonolog = ['пульмонол', 'пульмолог', 'пульмонал',
                                 'пульмоног']

Dermatolog = []
list_of_tokens_for_Dermatolog = ['дерматол']

LOR = []
list_of_tokens_for_LOR = ['лор', 'отоларин', 'отоларен']

Rentgenolog = []
list_of_tokens_for_Rentgenolog = ['рентгено']

# %%
df_for_Hirurg = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Ginekolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Urolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Okulist = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Terapevt = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Travmatolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Med_sestra = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Ortoped = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Onkolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Gastroenterolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Endokrinolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Allergolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Stomatolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Flebolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Anasteziolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Reanimatolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Nefrolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Narkolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Psihiatr = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Kardiolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Nevrolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Pylmonolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Dermatolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_LOR = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
df_for_Rentgenolog = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])

# %%
for hospital in tqdm(list_of_hospitals):  
    df = pd.read_excel(f'{hospital}.xlsx')

    post = df[['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust']]
    posts_1 = df['Текст отзыва']
    posts = []
    
    for text in posts_1:
        posts.append(str(text).lower())

    for count, value in enumerate(posts):
        for token in list_of_tokens_for_Hirurg:
            if token in value:
                df_for_Hirurg = df_for_Hirurg.append(post.iloc[[count]])

        for token in list_of_tokens_for_Ginekolog:
            if token in value:
                df_for_Ginekolog = df_for_Ginekolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Urolog:
            if token in value:
                df_for_Urolog = df_for_Urolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Okulist:
            if token in value:
                df_for_Okulist = df_for_Okulist.append(post.iloc[[count]])

        for token in list_of_tokens_for_Terapevt:
            if token in value:
                df_for_Terapevt = df_for_Terapevt.append(post.iloc[[count]])

        for token in list_of_tokens_for_Travmatolog:
            if token in value:
                df_for_Travmatolog = df_for_Travmatolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Med_sestra:
            if token in value:
                df_for_Med_sestra = df_for_Med_sestra.append(post.iloc[[count]])

        for token in list_of_tokens_for_Ortoped:
            if token in value:
                df_for_Ortoped = df_for_Ortoped.append(post.iloc[[count]])

        for token in list_of_tokens_for_Onkolog:
            if token in value:
                df_for_Onkolog = df_for_Onkolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Gastroenterolog:
            if token in value:
                df_for_Gastroenterolog = df_for_Gastroenterolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Endokrinolog:
            if token in value:
                 df_for_Endokrinolog = df_for_Endokrinolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Allergolog:
            if token in value:
                df_for_Allergolog = df_for_Allergolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Stomatolog:
            if token in value:
                df_for_Stomatolog = df_for_Stomatolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Flebolog:
            if token in value:
                df_for_Flebolog = df_for_Flebolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Anasteziolog:
            if token in value:
                df_for_Anasteziolog = df_for_Anasteziolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Reanimatolog:
            if token in value:
                df_for_Reanimatolog = df_for_Reanimatolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Nefrolog:
            if token in value:
                df_for_Nefrolog = df_for_Nefrolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Narkolog:
            if token in value:
                df_for_Narkolog = df_for_Narkolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Psihiatr:
            if token in value:
                df_for_Psihiatr = df_for_Psihiatr.append(post.iloc[[count]])

        for token in list_of_tokens_for_Kardiolog:
            if token in value:
                df_for_Kardiolog = df_for_Kardiolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Nevrolog:
            if token in value:
                df_for_Nevrolog = df_for_Nevrolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Pylmonolog:
            if token in value:
                df_for_Pylmonolog = df_for_Pylmonolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_Dermatolog:
            if token in value:
                df_for_Dermatolog = df_for_Dermatolog.append(post.iloc[[count]])

        for token in list_of_tokens_for_LOR:
            if token in value:
                df_for_LOR = df_for_LOR.append(post.iloc[[count]])

        for token in list_of_tokens_for_Rentgenolog:
            if token in value:
                df_for_Rentgenolog = df_for_Rentgenolog.append(post.iloc[[count]])

# %%
from tqdm.notebook import tqdm
import numpy as np
import matplotlib.pyplot as plt

full_df = pd.DataFrame(columns=['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust'])
for hospital in tqdm(list_of_hospitals):  
    df = pd.read_excel(f'{hospital}.xlsx')
    post = df[['Текст отзыва', 'neutral', 'happiness', 'sadness', 'enthusiasm', 'fear', 'anger', 'disgust']]
    full_df = full_df.append(post)
    
full_df_new = full_df.loc[full_df['neutral'] <= 0.9]
Недовольство = (np.log(list(full_df_new.fear)) + np.log(list(full_df_new.anger))) / 2
Позитив = np.log(1/(full_df_new.happiness))
norm_Позитив = (Позитив - min(Позитив)) / ((max(Позитив)) - (min(Позитив)))
norm_Недовольство = (Недовольство - min(Недовольство)) / ((max(Недовольство)) - (min(Недовольство)))
Pos = norm_Позитив / (norm_Позитив + norm_Недовольство)
target = Pos*(1-full_df_new['neutral'])*(1-full_df_new['enthusiasm'])
d_1 = list(target)
line_target_f = np.log(d_1[1:])

list_of_dfs = ['df_for_Hirurg_1', 'df_for_Ginekolog', 'df_for_Urolog', 'df_for_Okulist', 'df_for_Terapevt',
'df_for_Travmatolog', 'df_for_Med_sestra', 'df_for_Ortoped', 'df_for_Onkolog', 'df_for_Gastroenterolog',
'df_for_Endokrinolog' , 'df_for_Allergolog', 'df_for_Stomatolog', 'df_for_Flebolog', 'df_for_Anasteziolog', 
'df_for_Reanimatolog', 'df_for_Nefrolog', 'df_for_Narkolog', 'df_for_Psihiatr', 'df_for_Kardiolog',
'df_for_Nevrolog', 'df_for_Pylmonolog', 'df_for_Dermatolog', 'df_for_LOR', 'df_for_Rentgenolog']

for df in tqdm(list_of_dfs):
    test_df = pd.read_excel(f'{df}.xlsx')
    test_df = test_df.loc[test_df['neutral'] <= 0.9]
    Недовольство_ = (np.log(list(test_df.fear)) + np.log(list(test_df.anger))) / 2
    Позитив_ = np.log(1/(test_df.happiness))
    norm_Позитив = (Позитив_ - min(Позитив)) / ((max(Позитив)) - (min(Позитив)))
    norm_Недовольство = (Недовольство_ - min(Недовольство)) / ((max(Недовольство)) - (min(Недовольство)))
    Pos = norm_Позитив / (norm_Позитив + norm_Недовольство)
    target = Pos * (1-test_df['neutral'])*(1-test_df['enthusiasm'])
    line_target_ = np.log(target)
    line_target = 12*(line_target_ - min(line_target_f)) / (max(line_target_f) - min(line_target_f)) - 6
    logit = 1 / (1 + np.exp(-line_target))
    test_df['final_step'] = logit
    rang = []
    for x in list(test_df['final_step']):
        if x >= 0.9746:
            rang.append(1)
        else:
            rang.append(0)
    test_df['rang'] = rang
    test_df.to_excel(f'{df}.xlsx')
    
final_for_plot = {}

for df in tqdm(list_of_dfs):
    dff = pd.read_excel(f'{df}.xlsx')
    m = (sum(dff['rang']) / len(dff))
    final_for_plot[f'{df}'] = m
    
data = pd.DataFrame(dict(keys = list(final_for_plot.values()),
                         values = ['Hirurg', 'Ginekolog', 'Urolog', 'Okulist', 'Terapevt', 'Travmatolog', 'Med_sestra', 'Ortoped', 'Onkolog', 'Gastroenterolog', 'Endokrinolog', 'Allergolog', 'Stomatolog', 'Flebolog', 'Anasteziolog', 'Reanimatolog', 'Nefrolog', 'Narkolog', 'Psihiatr', 'Kardiolog', 'Nevrolog', 'Pylmonolog', 'Dermatolog', 'LOR', 'Rentgenolog']
                        ))
fig = px.line_polar(data, r='keys',
                    theta='values', line_close=True)
fig.update_traces(fill='toself')
fig.show()
